# %%
import pennylane as qml
from pennylane.optimize import AdamOptimizer, GradientDescentOptimizer
from pennylane import numpy as np
import math

import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Generation

# %%
np.random.seed(32)

# %%
alphas = [1, 2]
xdim = len(alphas)
xmin = [0]*xdim
xmax=[3.5]*xdim

# %%
### Data of g function distribution
### Cos함수와 관련된 데이터를 만드는 함수

# cos(alpha_0*x_0 + alpha_1*x_1 + ... + alpha_n*x_n)
def Cos(samples, alpha, xmin, xmax):
    """
    Generate datas we will use for the Model
    cos(alpha_0*x_0 + alpha_1*x_1 + ... + alpha_n*x_n)

    INPUT
    samples(int) : number of datas
    coefficients(array)\vec{\aplpha}] : coefficients for the x_i
    dim(int)[\vec{x}] : dimension of x data
    xmax : max value of each x_i
    xmin : min value of each x_i

    OUTPUT
    data sets(\vec{x}, cos(\vec{\alpha} \dot \vec{x}))
    """
    points= []
    results = []
    dim = len(alpha)

    def f(alpha, point):
        if len(alpha) != len(point):
            ValueError("dimension of alpha and x is not same")
    
        a = np.dot(alpha, point)
        return a

    # Mading sample points
    for i in range(samples):
        
        point = []
        for j in range(dim):
            x  = np.random.uniform(xmin[j], xmax[j])
            alpha0 = np.random.uniform(0, 5) ## cos(x*a + a0)
            point.append(x)


        result = np.cos(f(alpha, point)+alpha0)
        point.append(alpha0)

        points.append(point)
        results.append(result)

    return np.array(points, requires_grad = False), np.array(results, requires_grad = False)


# ------------------------------------------------------------------ #
Xdata, ydata = Cos(10, alphas, xmin , xmax)
print(Xdata.shape)
print(ydata)
print(Xdata[:,0])
# Out:
# (10, 3)
# [ 0.62468052 -0.07433959 -0.21050033 -0.96274148 -0.92009962  0.72776444
#   0.99985033 -0.94240215 -0.49711584 -0.85164865]
# [3.00611244 2.57834359 2.13188209 2.31963383 2.06290431 3.18817915
#  1.58206464 0.56218427 0.58275043 2.36192085]

# %%
Xdata[:,:len(xmin)].shape
# Out:
# (10, 2)

# %%
def plot_data(x, alpha, y, fig = None, ax = None):
    
    # Graph figure
    if fig == None :
        fig, ax = plt.subplots(1,1,figsize = (5, 5))
    
    def f(alpha, point):
        if len(alpha) != len(point):
            ValueError("dimension of alpha and x is not same")
    
        a = np.dot(alpha, point)
        return a
    
    for i in range(len(x)):
        x1 = f(alpha, x[i])
        x2 = y[i]
        s = np.linspace(0, 10)
        ax.scatter(x1, x2, alpha=0.5, color = 'c')
        ax.plot(s, np.cos(s), color = 'r')
        ax.set_xlabel("$x_{sum}$")
        ax.set_ylabel("$x_2$")

# ------------------------------------------------------------------ #

fig, ax = plt.subplots(figsize=(4, 4))
Xdata, ydata = Cos(1000, alphas, xmin=xmin, xmax = xmax)
plot_data(Xdata[:,:xdim], alphas, ydata, fig, ax) # for making cos(x*a + a0)

# %% [markdown]
# ### Variational Quantum Circuit Model

# %%
dev = qml.device("lightning.qubit", wires = 10)

@qml.qnode(dev)
def VQC_Model(thetas, phis, x, num_layers):
    """
    Variational Quantum Circuit model for Multi Variable Integration

    INPUT
    params : parameters for the circuit we will train them
    phis : array of parameters applied to the last RY gate
    x(Xdata[i]) : data point we have to upload
    num_layers : layers for the circuit

    OUTPUT
    Expectation value with PauliZ measure
    """
    
    dim = len(x)
    num_qubits = math.ceil(dim / 2)
    idx = 0

    params = list(thetas).copy()
    
    for _ in range(num_layers):
        for i in range(dim):
            qubit = i // 2
            qml.RY(params[idx], wires = qubit)
            qml.RZ(params[idx+1]*x[i], wires = qubit, id = f'x{i}') # Re-uploading data here
            qml.RZ(params[idx+2], wires = qubit)
            qml.RY(params[idx+3], wires = qubit)
            qml.RZ(params[idx+4], wires = qubit)
            idx += 5

        if num_qubits > 1:
            for q in range(0,num_qubits-1,1):
                qml.CZ([q, q+1])
            if num_qubits > 2:
                qml.CZ([num_qubits-1, 0])

    if num_qubits > 1:
        for i in range(num_qubits):
           qml.RY(phis[i], wires=i, id = f"phi{i}")
    
    obs = qml.PauliZ(0)
    for i in range(num_qubits-1):
         obs = obs @ qml.PauliZ(i+1)

    return qml.expval(obs)

# ------------------------------------------------------------------ #
Xdata, ydata = Cos(10, alphas, xmin, xmax)
x = Xdata[0]
dim = len(x)
num_layers = 2
num_qubits = math.ceil(len(x) / 2)

thetas = np.random.uniform(size = dim*num_layers*5,requires_grad = True)
phis = np.random.uniform(size = num_qubits, requires_grad =True)


print(thetas)
print(len(x))
print('------------------------------------------------------------------')
print(VQC_Model(thetas, phis, x, num_layers))
print('------------------------------------------------------------------')
fig, ax = qml.draw_mpl(VQC_Model)(thetas, phis, x, num_layers)
# Out:
# [0.50028869 0.64917717 0.35644878 0.49782099 0.62839642 0.58732291
#  0.6252324  0.80322709 0.42538971 0.82113603 0.80962243 0.50199182
#  0.1700525  0.57901331 0.96136725 0.17831195 0.17757634 0.71287992
#  0.81272047 0.75913276 0.38450963 0.98452915 0.55078779 0.46942546
#  0.59288762 0.95339546 0.97181311 0.08371261 0.10320619 0.94189236]
# 3
# ------------------------------------------------------------------
# 0.6223149035906596
# ------------------------------------------------------------------
# /home/kban/.local/lib/python3.8/site-packages/pennylane_lightning/lightning_qubit/lightning_qubit.py:822: UserWarning: Pre-compiled binaries for lightning.qubit are not available. Falling back to using the Python-based default.qubit implementation. To manually compile from source, follow the instructions at https://pennylane-lightning.readthedocs.io/en/latest/installation.html.
#   warn(

# %% [markdown]
# ### Cost function

# %%
def cost_function(thetas, phis, Xdata, num_layers, y):
    loss = 0.0

    for i in range(len(Xdata)):
        prediction = VQC_Model(thetas, phis, Xdata[i], num_layers)
        loss += (prediction - y[i])**2

    return loss / len(Xdata)

# ------------------------------------------------------------------ #

#Xdata, ydata = Cos(100, [1, 2, 1/2], 3, xmax=[np.pi, np.pi, np.pi], xmin = [0, 0, 0])
#x = Xdata[:20]
#dim = len(x)
#num_layers = 2
#num_qubits = math.ceil(len(x) / 2)

#thetas = np.random.uniform(size = dim*num_layers*5,requires_grad = True)
#phis = np.random.uniform(size = num_qubits, requires_grad =True)

#cost_function(thetas, phis, x, num_layers, ydata)

# %% [markdown]
# ### Model Running

# %%
def model_running(thetas, phis, x, num_layers):
    """
    Model running with given set of data.

    INPUT


    Returns
    Predicted labels for given data, Expectation value of the circuit
    """
    
    exepctation_values = []

    for i in range(len(x)):
        expval = VQC_Model(thetas, phis, x[i], num_layers)
        exepctation_values.append(expval)
        
    return np.array(exepctation_values)

# %%
def accuracy(ypred, ydata):

    ratio = []
    score = 0
    for i in range(len(ydata)):
        acc = ypred[i] / ydata[i] - 1
        if np.abs(acc) < 0.2:
            score += 1
        ratio.append(ypred[i] / ydata[i])

    return ratio, score/len(ydata)

# %%
def iterate_minibatches(inputs, targets, batch_size):
    """
    A generator for batches of the input data
    
    INPUT
    inputs : input data
    targets : targets
    batch_size : size of the batch, the number of datas in one batch

    Returns
    one batch of input data of length `batch_size`, one batch of targets of length `batch_size`
    """
    for start_idx in range(0, inputs.shape[0] - batch_size + 1, batch_size):
        idxs = slice(start_idx, start_idx + batch_size)
        yield inputs[idxs], targets[idxs]

# %% [markdown]
# -------------

# %%
### Preparing datas
train_data, train_target = Cos(250, alphas, xmin, xmax)
test_data, test_target = Cos(750, alphas, xmin, xmax)

# for making cos(x*a + a0)
x = train_data[0]
dim = len(x)

# Trainnig option settings
num_layers = 2
epochs = 100
batch_size = 50
lr = 0.03

# Using the Optimizer
opt = AdamOptimizer(lr)                 ### Adam Optimizer
#opt = GradientDescentOptimizer(lr)      ### GradientDescent based on Parmaeter Shift Rule

# Initializing random parameters for the circuit
thetas = np.random.uniform(size=dim*num_layers*5, requires_grad=True)
phis = np.random.uniform(size = num_qubits, requires_grad =True)

### Evaluating the qNN
# Running the model with test data
pred_train = model_running(thetas, phis, train_data, num_layers)
ratio_train, score_train = accuracy(pred_train, train_target)

# Running the model with the test data
pred_test = model_running(thetas, phis, test_data, num_layers)
ratio_test, score_test = accuracy(pred_test, test_target)

# Saving predictions with random weights for comparison 
initial_predictions = pred_test

loss = cost_function(thetas, phis, test_data, num_layers, test_target)

loss_list = [loss]
accuracy_train_list = [score_train]
accuracy_test_list = [score_test]

print(
    "Epoch: {:2d} | Cost: {:3f} | Train accuracy: {:3f} | Test Accuracy: {:3f}".format(
        0, loss.item(), score_train, score_test
    )
)

for it in range(epochs):
    for Xbatch, ybatch in iterate_minibatches(train_data, train_target, batch_size=batch_size):
        thetas, phis, _, _, _ = opt.step(cost_function, thetas, phis, Xbatch, num_layers, ybatch)

    pred_train = model_running(thetas, phis, train_data, num_layers)
    ratio_train, score_train = accuracy(pred_train, train_target)
    loss = cost_function(thetas, phis, train_data, num_layers, train_target)

    pred_test = model_running(thetas, phis, test_data, num_layers)
    ratio_test, score_test = accuracy(pred_test, test_target)
    res = [it + 1, loss.item(), score_train, score_test]
    print(
        "Epoch: {:2d} | Loss: {:3f} | Train accuracy: {:3f} | Test accuracy: {:3f}".format(
            *res
        )
    )

    loss_list.append(loss)
    accuracy_train_list.append(score_train)
    accuracy_test_list.append(score_test)
# Out:
# Epoch:  0 | Cost: 0.529253 | Train accuracy: 0.016000 | Test Accuracy: 0.013333
# Epoch:  1 | Loss: 0.452336 | Train accuracy: 0.016000 | Test accuracy: 0.014667
# Epoch:  2 | Loss: 0.434399 | Train accuracy: 0.016000 | Test accuracy: 0.026667
# Epoch:  3 | Loss: 0.429218 | Train accuracy: 0.008000 | Test accuracy: 0.030667
# Epoch:  4 | Loss: 0.420158 | Train accuracy: 0.020000 | Test accuracy: 0.025333
# Epoch:  5 | Loss: 0.410814 | Train accuracy: 0.016000 | Test accuracy: 0.025333
# Epoch:  6 | Loss: 0.403553 | Train accuracy: 0.032000 | Test accuracy: 0.030667
# Epoch:  7 | Loss: 0.393892 | Train accuracy: 0.040000 | Test accuracy: 0.036000
# Epoch:  8 | Loss: 0.381696 | Train accuracy: 0.040000 | Test accuracy: 0.041333
# Epoch:  9 | Loss: 0.365587 | Train accuracy: 0.048000 | Test accuracy: 0.044000
# Epoch: 10 | Loss: 0.343026 | Train accuracy: 0.068000 | Test accuracy: 0.050667
# Epoch: 11 | Loss: 0.312134 | Train accuracy: 0.072000 | Test accuracy: 0.062667
# Epoch: 12 | Loss: 0.273676 | Train accuracy: 0.092000 | Test accuracy: 0.076000
# Epoch: 13 | Loss: 0.229260 | Train accuracy: 0.132000 | Test accuracy: 0.084000
# Epoch: 14 | Loss: 0.180938 | Train accuracy: 0.192000 | Test accuracy: 0.097333
# Epoch: 15 | Loss: 0.130043 | Train accuracy: 0.220000 | Test accuracy: 0.152000
# Epoch: 16 | Loss: 0.080850 | Train accuracy: 0.324000 | Test accuracy: 0.248000
# Epoch: 17 | Loss: 0.042355 | Train accuracy: 0.468000 | Test accuracy: 0.401333
# Epoch: 18 | Loss: 0.022472 | Train accuracy: 0.600000 | Test accuracy: 0.556000
# Epoch: 19 | Loss: 0.015793 | Train accuracy: 0.644000 | Test accuracy: 0.626667
# Epoch: 20 | Loss: 0.011028 | Train accuracy: 0.704000 | Test accuracy: 0.712000
# Epoch: 21 | Loss: 0.006450 | Train accuracy: 0.784000 | Test accuracy: 0.802667
# Epoch: 22 | Loss: 0.003995 | Train accuracy: 0.816000 | Test accuracy: 0.814667
# Epoch: 23 | Loss: 0.002867 | Train accuracy: 0.860000 | Test accuracy: 0.842667
# Epoch: 24 | Loss: 0.002124 | Train accuracy: 0.884000 | Test accuracy: 0.850667
# Epoch: 25 | Loss: 0.001476 | Train accuracy: 0.920000 | Test accuracy: 0.889333
# Epoch: 26 | Loss: 0.001123 | Train accuracy: 0.948000 | Test accuracy: 0.896000
# Epoch: 27 | Loss: 0.001070 | Train accuracy: 0.928000 | Test accuracy: 0.884000
# Epoch: 28 | Loss: 0.000937 | Train accuracy: 0.920000 | Test accuracy: 0.884000
# Epoch: 29 | Loss: 0.000707 | Train accuracy: 0.944000 | Test accuracy: 0.904000
# Epoch: 30 | Loss: 0.000542 | Train accuracy: 0.960000 | Test accuracy: 0.913333
# Epoch: 31 | Loss: 0.000454 | Train accuracy: 0.980000 | Test accuracy: 0.926667
# Epoch: 32 | Loss: 0.000428 | Train accuracy: 0.976000 | Test accuracy: 0.926667
# Epoch: 33 | Loss: 0.000421 | Train accuracy: 0.968000 | Test accuracy: 0.926667
# Epoch: 34 | Loss: 0.000400 | Train accuracy: 0.968000 | Test accuracy: 0.922667
# Epoch: 35 | Loss: 0.000373 | Train accuracy: 0.976000 | Test accuracy: 0.920000
# Epoch: 36 | Loss: 0.000354 | Train accuracy: 0.976000 | Test accuracy: 0.918667
# Epoch: 37 | Loss: 0.000344 | Train accuracy: 0.968000 | Test accuracy: 0.921333
# Epoch: 38 | Loss: 0.000337 | Train accuracy: 0.964000 | Test accuracy: 0.921333
# Epoch: 39 | Loss: 0.000332 | Train accuracy: 0.960000 | Test accuracy: 0.918667
# Epoch: 40 | Loss: 0.000332 | Train accuracy: 0.956000 | Test accuracy: 0.917333
# Epoch: 41 | Loss: 0.000339 | Train accuracy: 0.956000 | Test accuracy: 0.913333
# Epoch: 42 | Loss: 0.000346 | Train accuracy: 0.948000 | Test accuracy: 0.910667
# Epoch: 43 | Loss: 0.000348 | Train accuracy: 0.948000 | Test accuracy: 0.912000
# Epoch: 44 | Loss: 0.000345 | Train accuracy: 0.948000 | Test accuracy: 0.912000
# Epoch: 45 | Loss: 0.000337 | Train accuracy: 0.948000 | Test accuracy: 0.912000
# Epoch: 46 | Loss: 0.000324 | Train accuracy: 0.948000 | Test accuracy: 0.913333
# Epoch: 47 | Loss: 0.000304 | Train accuracy: 0.952000 | Test accuracy: 0.917333
# Epoch: 48 | Loss: 0.000280 | Train accuracy: 0.956000 | Test accuracy: 0.917333
# Epoch: 49 | Loss: 0.000256 | Train accuracy: 0.960000 | Test accuracy: 0.920000
# Epoch: 50 | Loss: 0.000233 | Train accuracy: 0.964000 | Test accuracy: 0.921333
# Epoch: 51 | Loss: 0.000213 | Train accuracy: 0.976000 | Test accuracy: 0.926667
# Epoch: 52 | Loss: 0.000197 | Train accuracy: 0.976000 | Test accuracy: 0.930667
# Epoch: 53 | Loss: 0.000186 | Train accuracy: 0.976000 | Test accuracy: 0.936000
# Epoch: 54 | Loss: 0.000181 | Train accuracy: 0.976000 | Test accuracy: 0.936000
# Epoch: 55 | Loss: 0.000182 | Train accuracy: 0.976000 | Test accuracy: 0.934667
# Epoch: 56 | Loss: 0.000190 | Train accuracy: 0.976000 | Test accuracy: 0.933333
# Epoch: 57 | Loss: 0.000207 | Train accuracy: 0.976000 | Test accuracy: 0.926667
# Epoch: 58 | Loss: 0.000232 | Train accuracy: 0.960000 | Test accuracy: 0.926667
# Epoch: 59 | Loss: 0.000265 | Train accuracy: 0.948000 | Test accuracy: 0.920000
# Epoch: 60 | Loss: 0.000301 | Train accuracy: 0.940000 | Test accuracy: 0.912000
# Epoch: 61 | Loss: 0.000332 | Train accuracy: 0.940000 | Test accuracy: 0.910667
# Epoch: 62 | Loss: 0.000350 | Train accuracy: 0.932000 | Test accuracy: 0.909333
# Epoch: 63 | Loss: 0.000349 | Train accuracy: 0.928000 | Test accuracy: 0.910667
# Epoch: 64 | Loss: 0.000328 | Train accuracy: 0.936000 | Test accuracy: 0.910667
# Epoch: 65 | Loss: 0.000292 | Train accuracy: 0.944000 | Test accuracy: 0.914667
# Epoch: 66 | Loss: 0.000248 | Train accuracy: 0.952000 | Test accuracy: 0.918667
# Epoch: 67 | Loss: 0.000204 | Train accuracy: 0.964000 | Test accuracy: 0.929333
# Epoch: 68 | Loss: 0.000163 | Train accuracy: 0.972000 | Test accuracy: 0.933333
# Epoch: 69 | Loss: 0.000128 | Train accuracy: 0.984000 | Test accuracy: 0.945333
# Epoch: 70 | Loss: 0.000100 | Train accuracy: 0.992000 | Test accuracy: 0.952000
# Epoch: 71 | Loss: 0.000080 | Train accuracy: 0.992000 | Test accuracy: 0.960000
# Epoch: 72 | Loss: 0.000067 | Train accuracy: 0.992000 | Test accuracy: 0.961333
# Epoch: 73 | Loss: 0.000060 | Train accuracy: 0.992000 | Test accuracy: 0.962667
# Epoch: 74 | Loss: 0.000060 | Train accuracy: 0.992000 | Test accuracy: 0.960000
# Epoch: 75 | Loss: 0.000063 | Train accuracy: 0.992000 | Test accuracy: 0.960000
# Epoch: 76 | Loss: 0.000073 | Train accuracy: 0.992000 | Test accuracy: 0.960000
# Epoch: 77 | Loss: 0.000097 | Train accuracy: 0.984000 | Test accuracy: 0.956000
# Epoch: 78 | Loss: 0.000152 | Train accuracy: 0.976000 | Test accuracy: 0.944000
# Epoch: 79 | Loss: 0.000262 | Train accuracy: 0.948000 | Test accuracy: 0.922667
# Epoch: 80 | Loss: 0.000434 | Train accuracy: 0.928000 | Test accuracy: 0.905333
# Epoch: 81 | Loss: 0.000631 | Train accuracy: 0.900000 | Test accuracy: 0.877333
# Epoch: 82 | Loss: 0.000763 | Train accuracy: 0.900000 | Test accuracy: 0.864000
# Epoch: 83 | Loss: 0.000751 | Train accuracy: 0.900000 | Test accuracy: 0.857333
# Epoch: 84 | Loss: 0.000608 | Train accuracy: 0.912000 | Test accuracy: 0.874667
# Epoch: 85 | Loss: 0.000420 | Train accuracy: 0.932000 | Test accuracy: 0.898667
# Epoch: 86 | Loss: 0.000261 | Train accuracy: 0.948000 | Test accuracy: 0.914667
# Epoch: 87 | Loss: 0.000155 | Train accuracy: 0.972000 | Test accuracy: 0.929333
# Epoch: 88 | Loss: 0.000093 | Train accuracy: 0.988000 | Test accuracy: 0.945333
# Epoch: 89 | Loss: 0.000057 | Train accuracy: 0.992000 | Test accuracy: 0.957333
# Epoch: 90 | Loss: 0.000036 | Train accuracy: 0.992000 | Test accuracy: 0.962667
# Epoch: 91 | Loss: 0.000024 | Train accuracy: 0.996000 | Test accuracy: 0.976000
# Epoch: 92 | Loss: 0.000017 | Train accuracy: 0.996000 | Test accuracy: 0.986667
# Epoch: 93 | Loss: 0.000016 | Train accuracy: 0.996000 | Test accuracy: 0.990667
# Epoch: 94 | Loss: 0.000020 | Train accuracy: 0.996000 | Test accuracy: 0.985333
# Epoch: 95 | Loss: 0.000027 | Train accuracy: 0.996000 | Test accuracy: 0.976000
# Epoch: 96 | Loss: 0.000030 | Train accuracy: 0.996000 | Test accuracy: 0.970667
# Epoch: 97 | Loss: 0.000027 | Train accuracy: 0.996000 | Test accuracy: 0.973333
# Epoch: 98 | Loss: 0.000019 | Train accuracy: 0.996000 | Test accuracy: 0.984000
# Epoch: 99 | Loss: 0.000014 | Train accuracy: 0.996000 | Test accuracy: 0.986667
# Epoch: 100 | Loss: 0.000013 | Train accuracy: 0.996000 | Test accuracy: 0.993333

# %%
print(
    "Cost: {:3f} | Train accuracy {:3f} | Test Accuracy : {:3f}".format(
        loss, score_train, score_test
    )
)

print("Learned weights")
print("thetas = {}".format(thetas))
print("phis = {}".format(phis))

fig, axes = plt.subplots(1, 3, figsize=(10, 3))
plot_data(test_data[:,:xdim], alphas, initial_predictions, fig, axes[0])
plot_data(test_data[:,:xdim], alphas, pred_test, fig, axes[1])
plot_data(test_data[:,:xdim], alphas, test_target, fig, axes[2])

axes[0].set_title("Predictions with random parameters")
axes[1].set_title("Predictions after training")
axes[2].set_title("True test data")
plt.tight_layout()
plt.show()
# Out:
# Cost: 0.000013 | Train accuracy 0.996000 | Test Accuracy : 0.993333
# Learned weights
# thetas = [ 5.48827627e-02  1.13905728e-01  4.57813666e-02  5.62714156e-01
#  -8.54793681e-02  9.54313101e-01  1.88816701e+00 -5.98039551e-01
#   1.61123859e-03  3.64155606e-01  1.35409368e+00  6.31831974e-03
#   1.05422886e+00  4.51230658e-01  2.11005312e+00 -3.09078669e-02
#   9.93948724e-01 -5.48118757e-01  2.21706286e+00  5.30074779e-01
#   3.18036315e-01 -1.41389293e-01  1.48676021e+00  3.02670550e-01
#   9.14579394e-01  1.54693982e+00  1.00000821e+00  4.01296180e-01
#   5.64092097e-01 -1.92156036e-02]
# phis = [1.57681146 1.57888037]

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 6))

axes[0].plot(loss_list,'.-')
axes[1].plot(accuracy_test_list,'.-', label = 'Test_accuracy')
axes[1].plot(accuracy_train_list,'.-', label = 'Train_accuracy')
axes[0].legend()
axes[1].legend()
axes[1].set_ylim(top = 1.0)
axes[0].set_title(f"Loss(Layers = {num_layers})")
axes[1].set_title(f"Accuracy(Layers = {num_layers})")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Results for $g_{est}$

# %%
xlin = np.linspace(0, 3,100)
arr = np.zeros(100)
alpha0 = [1.25]*100


xlin_data1 = np.stack((xlin, arr, alpha0), axis=1)
xlin_data2 = np.stack((arr, xlin, alpha0), axis=1)
integral = 0
xlin_data = np.stack((xlin_data1, xlin_data2), axis=0)
for i in range(xdim):
        ypred = model_running(thetas, phis, xlin_data[i], num_layers)
        ytrue = np.cos(alphas[i]*xlin+alpha0)

        color = plt.rcParams["axes.prop_cycle"].by_key()["color"][i]

        plt.plot(xlin, 
                ypred,
                label=f"Approximation $x_{i+1}$",
                linewidth = 2.5,
                alpha = 0.6,
                ls = "-",
                color = color)

        plt.plot(
                xlin,
                ytrue,
                label=f"Target $x_{i+1}$",
                linewidth=1.5,
                alpha=0.8,
                ls="--",
                color=color)
        
plt.grid(True)
plt.title(f"dependent on each $x$")
plt.xlabel(f"$x_i$")
plt.ylabel(r"$g({\vec{x}})$")
plt.legend()
plt.show()

# %% [markdown]
# ### Results for $I(\cdots,x_{i-1},x_{i+1},\cdots)$

# %% [markdown]
# #### 변수 $x_2$와 $x_3$에 대한 적분을 수행하고 그 결과를 $ x_1 $값의 함수로 표현하고 싶다면, 우리는 두 변수에 대한 이중적분을 계산
#
# #### 함수 $ f(x_1, x_2, x_3) = \cos(x_1 + 2x_2 + 0.5x_3 + \alpha_0) $에 대해 $ \alpha_0 = 1.25 $로 고정하고, $ x_2 $와 $ x_3 $에 대해 0부터 3까지의 적분을 리만 적분으로 근사
#
# 1. **이중적분 설정**:
# $ I(x_1) = \int_{0}^{3} \int_{0}^{3} \cos(x_1 + 2x_2 + 0.5x_3 + 1.25) \, dx_2 \, dx_3 $
#
# 2. **구간 나누기**:
# 두 변수 $ x_2 $와 $ x_3 $에 대해 구간 [0, 3]을 $ N $개의 작은 구간으로 나눕니다. 각 변수에 대한 구간의 너비는 $ \Delta x = \frac{3 - 0}{N} $로 동일
#
# 3. **함수의 값 계산**:
# 이중 합을 사용하여 리만 합을 계산하기 위해, 각 구간에 대한 대표값 $ x_{2i} $와 $ x_{3j} $에서 함수의 값을 계산
#
# 4. **이중 리만 합 계산**:
# 각 대표값에서 함수의 값을 곱한 후, 모든 $ x_2 $와 $ x_3 $의 구간에 대해 이를 더하여 이중 리만 합을 계산
#
# $ I_{\text{Riemann}}(x_1) = \sum_{i=1}^{N} \sum_{j=1}^{N} \cos(x_1 + 2x_{2i} + 0.5x_{3j} + 1.25) \Delta x^2 $
#
# 5. **적분값 계산**:
# 리만 합을 계산한 후, $ N $을 충분히 크게 취하여 근사적분값 $ I_{\text{Riemann}}(x_1) $이 실제 이중적분 값에 근사됨
#
# 6. **결과 해석**:
# $ x_1 $에 대해 $ I_{\text{Riemann}}(x_1) $를 계산하면, 이는 $ x_1 $의 함수로서의 이중적분 결과를 얻을 수 있음

# %%
def ratio(pred, target, eps=1e-3):
    return np.abs(pred-target)/target
    # tts = np.where(np.abs(target) > eps, target, np.sign(target) * eps)
    # ccs = np.where(np.abs(pred) > eps, pred, np.sign(pred) * eps)
    # return np.abs(tts / ccs)

# %%
from multiprocessing import Pool
import time

# Define the integrand function
def integrand(thetas, phis, x, num_layers):
    return model_running(thetas, phis, x, num_layers)

# Set the value for alpha0
alpha0 = 1.25

# Set the bounds of the integration for x2 and x3
lower_bound = 0
upper_bound = 3

# Choose the number of points for the Riemann sum (more points -> better approximation)
N = 501  # This is an example; in practice, you might need a larger number for a good approximation
delta_x = (upper_bound - lower_bound) / (N-1)
xlin = np.linspace(0, 3,N - 1)


def compute_integral_for_x1(x1_data):
    x1, thetas, phis, alpha0, lower_bound, upper_bound, delta_x, N, num_layers = x1_data
    I_riemann_x1 = 0
    for i in range(N):
        x2 = lower_bound + i * delta_x
        int_data = np.array([[x1,x2,alpha0]], requires_grad=False)
        I_riemann_x1 += integrand(thetas, phis, int_data, num_layers) * delta_x ** (xdim-1)
    return I_riemann_x1.item()

def integrand_parallel(thetas, phis, alpha0, lower_bound, upper_bound, delta_x, N, num_layers, xlin):
    start_time = time.time()  # 시간 측정 시작
    # Prepare data for each x1 to be used in parallel processing
    tasks = [(x1, thetas, phis, alpha0, lower_bound, upper_bound, delta_x, N, num_layers) for x1 in xlin]

    # Use all available CPUs
    with Pool() as pool:
        integral_results_ = pool.map(compute_integral_for_x1, tasks)
    end_time = time.time()  # 시간 측정 종료
    print(f"Parallel processing took {end_time - start_time} seconds.")    
    return integral_results_


# Use the parallel function
integral_results_ = integrand_parallel(thetas, phis, alpha0, lower_bound, upper_bound, delta_x, N, num_layers, xlin)
# Out:
# Parallel processing took 44.13914489746094 seconds.

# %%
# To-do: numerical integration results, maybe we can use integrand with true g(x,a)
# ytrue = -0.943495985118008*np.sin(xlin) - 0.170911422467665*np.cos(xlin)
ytrue = 0.126300905446713*np.sin(xlin) - 0.0629518701720403*np.cos(xlin)

# %%
i = 1 # x_1

fig, (ax1, ax2) = plt.subplots(
    2, 1, sharex=True, figsize=(6, 6 * 6 / 8), gridspec_kw={"height_ratios": [5, 2]}
)

ax1.plot(xlin, 
        integral_results_,
        label=f"Approximation $x_{i}$",
        linewidth = 2.5,  ls="-.", color="black", alpha=0.7)

ax1.plot(
        xlin,
        ytrue,
        label=f"Target $x_{i}$",
        linewidth=2.5,
        alpha=0.5,
        color='red')
        
ax1.grid(True)
ax1.set_title(f"Integral results with $a_0 = {alpha0}$")
ax1.set_xlabel(f"$x_i$")
ax1.set_ylabel(r"$dI({\vec{x}})/dx$")
ax1.legend()


rr = ratio(integral_results_, ytrue)

# r1 = ratio(c_p, target_vals)
# r2 = ratio(c_m, target_vals)
# rp = np.maximum(r1, r2)
# rm = np.minimum(r1, r2)
# fig.legend(bbox_to_anchor=(0.85, 0.88), framealpha=1)

ax2.plot(xlin, rr, alpha=0.9, lw=2.5)
ax2.hlines(0, 0, 3, color="black", alpha=0.7, ls="-.", lw=1.5)
ax2.set_ylim(-1,1)
ax2.set_ylabel("|T-P|/T")
ax2.grid(False)
ax2.set_xlabel(rf"$x_{i}$")
# Out:
# Text(0.5, 0, '$x_1$')

# %%
from multiprocessing import Pool
import time

# Define the integrand function
def integrand(thetas, phis, x, num_layers):
    return model_running(thetas, phis, x, num_layers)

# Set the value for alpha0
alpha0 = 4

# Set the bounds of the integration for x2 and x3
lower_bound = 0
upper_bound = 3

# Choose the number of points for the Riemann sum (more points -> better approximation)
N = 501  # This is an example; in practice, you might need a larger number for a good approximation
delta_x = (upper_bound - lower_bound) / (N-1)
xlin = np.linspace(0, 3,N - 1)


def compute_integral_for_x1(x1_data):
    x1, thetas, phis, alpha0, lower_bound, upper_bound, delta_x, N, num_layers = x1_data
    I_riemann_x1 = 0
    for i in range(N):
        x2 = lower_bound + i * delta_x
        int_data = np.array([[x1,x2,alpha0]], requires_grad=False)
        I_riemann_x1 += integrand(thetas, phis, int_data, num_layers) * delta_x ** (xdim-1)
    return I_riemann_x1.item()

def integrand_parallel(thetas, phis, alpha0, lower_bound, upper_bound, delta_x, N, num_layers, xlin):
    start_time = time.time()  # 시간 측정 시작
    # Prepare data for each x1 to be used in parallel processing
    tasks = [(x1, thetas, phis, alpha0, lower_bound, upper_bound, delta_x, N, num_layers) for x1 in xlin]

    # Use all available CPUs
    with Pool() as pool:
        integral_results_ = pool.map(compute_integral_for_x1, tasks)
    end_time = time.time()  # 시간 측정 종료
    print(f"Parallel processing took {end_time - start_time} seconds.")    
    return integral_results_


# Use the parallel function
integral_results_ = integrand_parallel(thetas, phis, alpha0, lower_bound, upper_bound, delta_x, N, num_layers, xlin)
# Out:
# Parallel processing took 42.748173236846924 seconds.

# %%
# To-do: numerical integration results, maybe we can use integrand with true g(x,a)
# ytrue = -0.943495985118008*np.sin(xlin) - 0.170911422467665*np.cos(xlin)
ytrue = -np.sin(xlin + 4)/2 + np.sin(xlin + 10)/2

# %%
i = 1 # x_1

fig, (ax1, ax2) = plt.subplots(
    2, 1, sharex=True, figsize=(6, 6 * 6 / 8), gridspec_kw={"height_ratios": [5, 2]}
)

ax1.plot(xlin, 
        integral_results_,
        label=f"Approximation $x_{i}$",
        linewidth = 2.5,  ls="-.", color="black", alpha=0.7)

ax1.plot(
        xlin,
        ytrue,
        label=f"Target $x_{i}$",
        linewidth=2.5,
        alpha=0.5,
        color='red')
        
ax1.grid(True)
ax1.set_title(f"Integral results with $a_0 = {alpha0}$")
ax1.set_xlabel(f"$x_i$")
ax1.set_ylabel(r"$dI({\vec{x}})/dx$")
ax1.legend()


rr = ratio(integral_results_, ytrue)

# r1 = ratio(c_p, target_vals)
# r2 = ratio(c_m, target_vals)
# rp = np.maximum(r1, r2)
# rm = np.minimum(r1, r2)
# fig.legend(bbox_to_anchor=(0.85, 0.88), framealpha=1)

ax2.plot(xlin, rr, alpha=0.9, lw=2.5)
ax2.hlines(0, 0, 3, color="black", alpha=0.7, ls="-.", lw=1.5)
ax2.set_ylim(-1,1)
ax2.set_ylabel("|T-P|/T")
ax2.grid(False)
ax2.set_xlabel(rf"$x_{i}$")
# Out:
# Text(0.5, 0, '$x_1$')
